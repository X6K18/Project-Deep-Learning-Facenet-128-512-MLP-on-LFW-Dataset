# %%
import cv2
import matplotlib.pyplot as plt

# ==================== ĐƯỜNG DẪN ẢNH ====================
image_path = 'documents/pipeline.png'   # ←←← THAY ĐƯỜNG DẪN NẾU CẦN

# Đọc ảnh
pipeline_img = cv2.imread(image_path)

# ==================== KIỂM TRA LỖI ====================
if pipeline_img is None:
    print("LỖI: Không đọc được ảnh!")
    print(f"→ Đường dẫn bạn dùng: '{image_path}'")
    print("→ Hãy kiểm tra:")
    print("   1. File có tồn tại không?")
    print("   2. Đường dẫn có đúng không? (phân biệt hoa/thường)")
    print("   3. Notebook đang chạy ở thư mục nào?")
    import os
    print(f"   Thư mục hiện tại: {os.getcwd()}")
    print(f"   Các file trong thư mục 'documents': {os.listdir('documents') if os.path.exists('documents') else 'Thư mục documents không tồn tại!'}")
else:
    print(f"Đọc ảnh thành công! Kích thước: {pipeline_img.shape}")
    
    # Chuyển sang RGB để hiển thị đúng màu với matplotlib
    img_rgb = cv2.cvtColor(pipeline_img, cv2.COLOR_BGR2RGB)
    
    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    plt.title('Pipeline Image')
    plt.axis('off')
    plt.show()
# Out:
# Đọc ảnh thành công! Kích thước: (768, 1408, 3)

# %% [markdown]
# **embedding_objs = DeepFace.represent(img_path=img_path, model_name=MODEL_NAME, enforce_detection=False)**

# %%
deepface_img = cv2.imread('documents/deepface.png')

imgdf_rgb = cv2.cvtColor(deepface_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 8))
plt.imshow(imgdf_rgb)
plt.title('Pipeline Image')
plt.axis('off')
plt.show()
